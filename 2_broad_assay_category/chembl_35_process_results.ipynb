# %% [markdown]
# This notebook takes the results from the broad assay category model predictions ChEMBL 35 and formats the results for a better output file for inspecting, further use and presentation

# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn'

# %%
results = pd.read_csv('chembl_35_broad_results.txt', sep='\t')

# %%
results.head()
# Out:
#    Unnamed: 0  assay_id    year  \
# 0           0        89  1994.0
# 1           1       235  2003.0
# 2           2       667  2003.0
# 3           3       758  2001.0
# 4           4      1155  1992.0
#
#                                          description assay_type  \
# 0  Evaluated for its activity to inhibit rat live...          B
# 1  Inhibitory activity against inosine 5'-inosine...          B
# 2  5-hydroxytryptamine 1A receptor antagonism was...          F
# 3  Binding affinity towards human 5-hydroxytrypta...          B
# 4  Compound was evaluated for in vitro binding af...          B
#
#                                                 cats
# 0  {'Radioligand binding (BAO_0002776)': 0.000140...
# 1  {'Radioligand binding (BAO_0002776)': 4.709044...
# 2  {'Radioligand binding (BAO_0002776)': 0.749271...
# 3  {'Radioligand binding (BAO_0002776)': 0.001449...
# 4  {'Radioligand binding (BAO_0002776)': 0.999997...

# %%
# This cell takes a few minutes
results['cats_df'] = results['cats'].apply(lambda x: eval(x))

# %%
results.head()
# Out:
#    Unnamed: 0  assay_id    year  \
# 0           0        89  1994.0
# 1           1       235  2003.0
# 2           2       667  2003.0
# 3           3       758  2001.0
# 4           4      1155  1992.0
#
#                                          description assay_type  \
# 0  Evaluated for its activity to inhibit rat live...          B
# 1  Inhibitory activity against inosine 5'-inosine...          B
# 2  5-hydroxytryptamine 1A receptor antagonism was...          F
# 3  Binding affinity towards human 5-hydroxytrypta...          B
# 4  Compound was evaluated for in vitro binding af...          B
#
#                                                 cats  \
# 0  {'Radioligand binding (BAO_0002776)': 0.000140...
# 1  {'Radioligand binding (BAO_0002776)': 4.709044...
# 2  {'Radioligand binding (BAO_0002776)': 0.749271...
# 3  {'Radioligand binding (BAO_0002776)': 0.001449...
# 4  {'Radioligand binding (BAO_0002776)': 0.999997...
#
#                                              cats_df
# 0  {'Radioligand binding (BAO_0002776)': 0.000140...
# 1  {'Radioligand binding (BAO_0002776)': 4.709044...
# 2  {'Radioligand binding (BAO_0002776)': 0.749271...
# 3  {'Radioligand binding (BAO_0002776)': 0.001449...
# 4  {'Radioligand binding (BAO_0002776)': 0.999997...

# %%
def find_cat_prediction(x, column_name):
    prediction_value = x[column_name]
    return prediction_value

# %%
keys = results.iloc[0]['cats_df'].keys()
keys
# Out:
# dict_keys(['Radioligand binding (BAO_0002776)', 'Binding (BAO_0002989)', 'Protein activity (BAO_0013016)', 'in vivo method (BAO_0040021)', 'Cell phenotype (BAO_0002542)', 'Nucleic acid binding', 'Antimicrobial activity'])

# %%
for column_name in keys:
    print(column_name)
# Out:
# Radioligand binding (BAO_0002776)
# Binding (BAO_0002989)
# Protein activity (BAO_0013016)
# in vivo method (BAO_0040021)
# Cell phenotype (BAO_0002542)
# Nucleic acid binding
# Antimicrobial activity

# %%
for column_name in keys:
    results[column_name] = results['cats_df'].apply(lambda x: find_cat_prediction(x, column_name))

# %%
results.head()
# Out:
#    Unnamed: 0  assay_id    year  \
# 0           0        89  1994.0
# 1           1       235  2003.0
# 2           2       667  2003.0
# 3           3       758  2001.0
# 4           4      1155  1992.0
#
#                                          description assay_type  \
# 0  Evaluated for its activity to inhibit rat live...          B
# 1  Inhibitory activity against inosine 5'-inosine...          B
# 2  5-hydroxytryptamine 1A receptor antagonism was...          F
# 3  Binding affinity towards human 5-hydroxytrypta...          B
# 4  Compound was evaluated for in vitro binding af...          B
#
#                                                 cats  \
# 0  {'Radioligand binding (BAO_0002776)': 0.000140...
# 1  {'Radioligand binding (BAO_0002776)': 4.709044...
# 2  {'Radioligand binding (BAO_0002776)': 0.749271...
# 3  {'Radioligand binding (BAO_0002776)': 0.001449...
# 4  {'Radioligand binding (BAO_0002776)': 0.999997...
#
#                                              cats_df  \
# 0  {'Radioligand binding (BAO_0002776)': 0.000140...
# 1  {'Radioligand binding (BAO_0002776)': 4.709044...
# 2  {'Radioligand binding (BAO_0002776)': 0.749271...
# 3  {'Radioligand binding (BAO_0002776)': 0.001449...
# 4  {'Radioligand binding (BAO_0002776)': 0.999997...
#
#    Radioligand binding (BAO_0002776)  Binding (BAO_0002989)  \
# 0                           0.000141               0.020719
# 1                           0.000047               0.000101
# 2                           0.749272               0.003896
# 3                           0.001450               0.999711
# 4                           0.999998               0.000010
#
#    Protein activity (BAO_0013016)  in vivo method (BAO_0040021)  \
# 0                        0.820549                      0.000340
# 1                        0.760096                      0.000034
# 2                        0.000237                      0.000165
# 3                        0.000007                      0.000063
# 4                        0.000030                      0.001088
#
#    Cell phenotype (BAO_0002542)  Nucleic acid binding  Antimicrobial activity
# 0                      0.000403              0.000183                0.004031
# 1                      0.368850              0.000012                0.003083
# 2                      0.005068              0.005397                0.000072
# 3                      0.000013              0.000615                0.000136
# 4                      0.000005              0.000031                0.000692

# %%
results['predicted_cat'] = results['cats_df'].apply(lambda x: max(x.items(), key=lambda k: k[1])[0])
results['prediction_score'] = results['cats_df'].apply(lambda x: max(x.items(), key=lambda k: k[1])[1])

# %%
results['second_largest_score'] = results['cats_df'].apply(lambda x: sorted(x.values())[-2]) # Get the second largest value

# %%
results['predicted_category'] = results['predicted_cat'].apply(lambda x: x.split(' (')[0])

# %%
results['predicted_cat'].drop_duplicates()
# Out:
# 0         Protein activity (BAO_0013016)
# 2      Radioligand binding (BAO_0002776)
# 3                  Binding (BAO_0002989)
# 21          Cell phenotype (BAO_0002542)
# 33          in vivo method (BAO_0040021)
# 41                Antimicrobial activity
# 147                 Nucleic acid binding
# Name: predicted_cat, dtype: object

# %%
results['predicted_bao_id'] = results['predicted_cat'].apply(lambda x: x.split(' (')[1].rstrip(')') if '(' in x else np.nan)

# %%
bao_term_dict = {
    'BAO_0013016': 'functional target-based'
    , 'BAO_0002989': 'binding assay'
    , 'BAO_0002776': 'radioligand binding assay'
    , 'BAO_0002542': 'cell phenotype'
    , 'BAO_0040021': 'in vivo assay method'
}

# %%
# Fill in bao preferred terms
results['predicted_bao_term'] = results['predicted_bao_id'].apply(lambda x: bao_term_dict[x] if x is not np.nan else np.nan)

# %%
results[['predicted_category', 'predicted_bao_term', 'predicted_bao_id']].drop_duplicates()
# Out:
#          predicted_category         predicted_bao_term predicted_bao_id
# 0          Protein activity    functional target-based      BAO_0013016
# 2       Radioligand binding  radioligand binding assay      BAO_0002776
# 3                   Binding              binding assay      BAO_0002989
# 21           Cell phenotype             cell phenotype      BAO_0002542
# 33           in vivo method       in vivo assay method      BAO_0040021
# 41   Antimicrobial activity                        NaN              NaN
# 147    Nucleic acid binding                        NaN              NaN

# %%
results.columns
# Out:
# Index(['Unnamed: 0', 'assay_id', 'year', 'description', 'assay_type', 'cats',
#        'cats_df', 'Radioligand binding (BAO_0002776)', 'Binding (BAO_0002989)',
#        'Protein activity (BAO_0013016)', 'in vivo method (BAO_0040021)',
#        'Cell phenotype (BAO_0002542)', 'Nucleic acid binding',
#        'Antimicrobial activity', 'predicted_cat', 'prediction_score',
#        'second_largest_score', 'predicted_category', 'predicted_bao_id',
#        'predicted_bao_term'],
#       dtype='object')

# %%
chosen_columns = ['assay_id'
                  , 'year'
                  , 'description'
                  , 'assay_type'
                  , 'predicted_category'
                  , 'prediction_score'
                  , 'predicted_bao_id'
                  , 'predicted_bao_term'
                  , 'Radioligand binding (BAO_0002776)'
                  , 'Binding (BAO_0002989)'
                  , 'Protein activity (BAO_0013016)'
                  , 'in vivo method (BAO_0040021)'
                  , 'Cell phenotype (BAO_0002542)'
                  , 'Nucleic acid binding'
                  , 'Antimicrobial activity'
                 ]

# %%
results[chosen_columns].head()
# Out:
#    assay_id    year                                        description  \
# 0        89  1994.0  Evaluated for its activity to inhibit rat live...
# 1       235  2003.0  Inhibitory activity against inosine 5'-inosine...
# 2       667  2003.0  5-hydroxytryptamine 1A receptor antagonism was...
# 3       758  2001.0  Binding affinity towards human 5-hydroxytrypta...
# 4      1155  1992.0  Compound was evaluated for in vitro binding af...
#
#   assay_type   predicted_category  prediction_score predicted_bao_id  \
# 0          B     Protein activity          0.820549      BAO_0013016
# 1          B     Protein activity          0.760096      BAO_0013016
# 2          F  Radioligand binding          0.749272      BAO_0002776
# 3          B              Binding          0.999711      BAO_0002989
# 4          B  Radioligand binding          0.999998      BAO_0002776
#
#           predicted_bao_term  Radioligand binding (BAO_0002776)  \
# 0    functional target-based                           0.000141
# 1    functional target-based                           0.000047
# 2  radioligand binding assay                           0.749272
# 3              binding assay                           0.001450
# 4  radioligand binding assay                           0.999998
#
#    Binding (BAO_0002989)  Protein activity (BAO_0013016)  \
# 0               0.020719                        0.820549
# 1               0.000101                        0.760096
# 2               0.003896                        0.000237
# 3               0.999711                        0.000007
# 4               0.000010                        0.000030
#
#    in vivo method (BAO_0040021)  Cell phenotype (BAO_0002542)  \
# 0                      0.000340                      0.000403
# 1                      0.000034                      0.368850
# 2                      0.000165                      0.005068
# 3                      0.000063                      0.000013
# 4                      0.001088                      0.000005
#
#    Nucleic acid binding  Antimicrobial activity
# 0              0.000183                0.004031
# 1              0.000012                0.003083
# 2              0.005397                0.000072
# 3              0.000615                0.000136
# 4              0.000031                0.000692

# %%
results[chosen_columns].to_csv('chembl_35_broad_results_processed.txt', sep='\t', index=False)
